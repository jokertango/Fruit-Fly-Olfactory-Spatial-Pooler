# %% [markdown]
# ## Olfactory Nupic Spatial Pooling with Variable Learning Rates

# %%
import csv
import datetime
import numpy 
import os
import yaml
import seaborn as sns
import pandas as pd
import plotly.plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt


from nupic.algorithms.sdr_classifier_factory import SDRClassifierFactory
from nupic.algorithms.spatial_pooler import SpatialPooler
from nupic.algorithms.temporal_memory import TemporalMemory
#import date encoder
from nupic.encoders.date import DateEncoder
#import RandomDistributedScalarEncoder
from nupic.encoders.random_distributed_scalar import \
  RandomDistributedScalarEncoder
#import normal ScalarEncoder
from nupic.encoders import ScalarEncoder
#category encoder
from nupic.encoders.category import CategoryEncoder

# %% [markdown]
# ## Model Params

# %%
# Model Params!
MODEL_PARAMS = {
    # Type of model that the rest of these parameters apply to.
    'model': "Classification",

    # Version that specifies the format of the config.
    'version': 1,

    # Intermediate variables used to compute fields in modelParams and also
    # referenced from the control section.
    'aggregationInfo': {   'days': 0,
        'fields': [('chem1', 'sum')],
        'hours': 1,
        'microseconds': 0,
        'milliseconds': 0,
        'minutes': 0,
        'months': 0,
        'seconds': 0,
        'weeks': 0,
        'years': 0},

    'predictAheadTime': None,

    # Model parameter dictionary.
    'modelParams': {
        # The type of inference that this model will perform
        'inferenceType': 'TemporalAnomaly',

        'sensorParams': {
            # Sensor diagnostic output verbosity control;
            # if > 0: sensor region will print out on screen what it's sensing
            # at each step 0: silent; >=1: some info; >=2: more info;
            # >=3: even more info (see compute() in py/regions/RecordSensor.py)
            'verbosity' : 0,

            # Include the encoders we use
            'encoders': {
                u'timestamp_timeOfDay': {
                    'fieldname': u'timestamp',
                    'name': u'timestamp_timeOfDay',
                    'timeOfDay': (21, 0.5),
                    'type': 'DateEncoder'},
                u'timestamp_dayOfWeek': None,
                u'timestamp_weekend': { 
                    'fieldname': u'timestamp',
                    'name': u' timestamp_weekend',
                    'weekend': 21,
                    'type': 'DateEncoder'}, 
                u'chem1':{
                    'clipInput': True,
                    'fieldname': u'chem1',
                    'maxval': 100.0,
                    'minval': 0.0,
                    'n': 50,
                    'name': u'c1',
                    'type': 'ScalarEncoder',
                    'w': 21,
                    'resolution':0.88},
                u'chem1':{
                    'clipInput': True,
                    'fieldname': u'chem1',
                    'maxval': 100.0,
                    'minval': 0.0,
                    'n': 50,
                    'name': u'c1',
                    'type': 'ScalarEncoder',
                    'w': 21,
                    'resolution':0.88},
                u'chem2':{
                    'clipInput': True,
                    'fieldname': u'chem2',
                    'maxval': 100.0,
                    'minval': 0.0,
                    'n': 50,
                    'name': u'c1',
                    'type': 'ScalarEncoder',
                    'w': 21,
                    'resolution':0.88},
                u'chem3':{
                    'clipInput': True,
                    'fieldname': u'chem3',
                    'maxval': 100.0,
                    'minval': 0.0,
                    'n': 50,
                    'name': u'c1',
                    'type': 'ScalarEncoder',
                    'w': 21,
                    'resolution':0.88},
                u'chem4':{
                    'clipInput': True,
                    'fieldname': u'chem4',
                    'maxval': 100.0,
                    'minval': 0.0,
                    'n': 50,
                    'name': u'c1',
                    'type': 'ScalarEncoder',
                    'w': 21,
                    'resolution':0.88},
                u'scent':{'fieldname': u'scent',
                    'categoryList':['lemon','flower','dog','sugar'],
                    'forced':False,
                    'name': u'chem',
                    'type': 'CategoryEncoder',
                    'w': 21,
                    'resolution':0.88},},
            # CategoryEncoder(self, w, categoryList, name='category', verbosity=0, forced=False)
            # A dictionary specifying the period for automatically-generated
            # resets from a RecordSensor;
            #
            # None = disable automatically-generated resets (also disabled if
            # all of the specified values evaluate to 0).
            # Valid keys is the desired combination of the following:
            #   days, hours, minutes, seconds, milliseconds, microseconds, weeks
            #
            # Example for 1.5 days: sensorAutoReset = dict(days=1,hours=12),
            #
            # (value generated from SENSOR_AUTO_RESET)
            'sensorAutoReset' : None,
        },

        'spEnable': True,

        'spParams': {
            # SP diagnostic output verbosity control;
            # 0: silent; >=1: some info; >=2: more info;
            'spVerbosity' : 0,

            # Spatial Pooler implementation selector, see getSPClass
            # in py/regions/SPRegion.py for details
            # 'py' (default), 'cpp' (speed optimized, new)
            'spatialImp' : 'cpp',

            'globalInhibition': 1,

            # Number of cell columns in the cortical region (same number for
            # SP and TM)
            # (see also tpNCellsPerCol)
            'columnCount': 2650,

            'inputWidth': 0,

            # SP inhibition control (absolute value);
            # Maximum number of active columns in the SP region's output (when
            # there are more, the weaker ones are suppressed)
            'numActiveColumnsPerInhArea': 40,

            'seed': 1956,

            # potentialPct
            # What percent of the columns's receptive field is available
            # for potential synapses. At initialization time, we will
            # choose potentialPct * (2*potentialRadius+1)^2
            'potentialPct': 0.5,
            'localAreaDensity': -1.0,
            'boostStrength': 0.0,

            # The default connected threshold. Any synapse whose
            # permanence value is above the connected threshold is
            # a "connected synapse", meaning it can contribute to the
            # cell's firing. Typical value is 0.10. Cells whose activity
            # level before inhibition falls below minDutyCycleBeforeInh
            # will have their own internal synPermConnectedCell
            # threshold set below this default value.
            # (This concept applies to both SP and TM and so 'cells'
            # is correct here as opposed to 'columns')
            'synPermConnected': 0.1,

            'synPermActiveInc': 0.1,

            'synPermInactiveDec': 0.005,
        },

        # Controls whether TM is enabled or disabled;
        # TM is necessary for making temporal predictions, such as predicting
        # the next inputs.  Without TP, the model is only capable of
        # reconstructing missing sensor inputs (via SP).
        'tmEnable' : False,

        'tmParams': {
            # TM diagnostic output verbosity control;
            # 0: silent; [1..6]: increasing levels of verbosity
            # (see verbosity in nupic/trunk/py/nupic/research/TP.py and BacktrackingTMCPP.py)
            'verbosity': 0,

            # Number of cell columns in the cortical region (same number for
            # SP and TM)
            # (see also tpNCellsPerCol)
            'columnCount': 2650,

            # The number of cells (i.e., states), allocated per column.
            'cellsPerColumn': 32,

            'inputWidth': 2048,

            'seed': 1960,

            # Temporal Pooler implementation selector (see _getTPClass in
            # CLARegion.py).
            'temporalImp': 'cpp',

            # New Synapse formation count
            # NOTE: If None, use spNumActivePerInhArea
            #
            # TODO: need better explanation
            'newSynapseCount': 20,

            # Maximum number of synapses per segment
            #  > 0 for fixed-size CLA
            # -1 for non-fixed-size CLA
            #
            # TODO: for Ron: once the appropriate value is placed in TP
            # constructor, see if we should eliminate this parameter from
            # description.py.
            'maxSynapsesPerSegment': 32,

            # Maximum number of segments per cell
            #  > 0 for fixed-size CLA
            # -1 for non-fixed-size CLA
            #
            # TODO: for Ron: once the appropriate value is placed in TP
            # constructor, see if we should eliminate this parameter from
            # description.py.
            'maxSegmentsPerCell': 128,

            # Initial Permanence
            # TODO: need better explanation
            'initialPerm': 0.21,

            # Permanence Increment
            'permanenceInc': 0.1,

            # Permanence Decrement
            # If set to None, will automatically default to tpPermanenceInc
            # value.
            'permanenceDec' : 0.1,

            'globalDecay': 0.0,

            'maxAge': 0,

            # Minimum number of active synapses for a segment to be considered
            # during search for the best-matching segments.
            # None=use default
            # Replaces: tpMinThreshold
            'minThreshold': 9,

            # Segment activation threshold.
            # A segment is active if it has >= tpSegmentActivationThreshold
            # connected synapses that are active due to infActiveState
            # None=use default
            # Replaces: tpActivationThreshold
            'activationThreshold': 12,

            'outputType': 'normal',

            # "Pay Attention Mode" length. This tells the TM how many new
            # elements to append to the end of a learned sequence at a time.
            # Smaller values are better for datasets with short sequences,
            # higher values are better for datasets with long sequences.
            'pamLength': 1,
        },

        'clParams': {
            'regionName' : 'SDRClassifierRegion',

            # Classifier diagnostic output verbosity control;
            # 0: silent; [1..6]: increasing levels of verbosity
            'verbosity' : 0,

            # This controls how fast the classifier learns/forgets. Higher values
            # make it adapt faster and forget older patterns faster.
            'alpha': 0.005,

            # This is set after the call to updateConfigFromSubConfig and is
            # computed from the aggregationInfo and predictAheadTime.
            'steps': '1',

            'implementation': 'cpp',
        },

        'anomalyParams': {
            u'anomalyCacheRecords': None,
            u'autoDetectThreshold': None,
            u'autoDetectWaitRecords': 2184
        },

        'trainSPNetOnlyIfRequested': False,
    },
}

# %% [markdown]
# ## Encoding Data

# %%
_NUM_RECORDS = 16000
_EXAMPLE_DIR = os.path.dirname(os.path.abspath('/Users/adamcasper/nupic/examples'))
_INPUT_FILE_PATH = "data50_with_dopa.csv"

# %%
#feeding model params to different encoders
modelParams = MODEL_PARAMS["modelParams"]
enParams = modelParams["sensorParams"]["encoders"]
spParams = modelParams["spParams"]
tmParams = modelParams["tmParams"]


#encodes time of day
#timeOfDayEncoder = DateEncoder(
#timeOfDay=enParams["timestamp_timeOfDay"]["timeOfDay"])
#encodes weekend
#weekendEncoder = DateEncoder(
#weekend=enParams["timestamp_weekend"]["weekend"])
#scalar encoder for chem1
scalarEncoder = RandomDistributedScalarEncoder(
enParams["chem1"]['resolution'])
#scalar encoder for chem2
scalarEncoder = RandomDistributedScalarEncoder(
enParams["chem2"]['resolution'])
#scalar encoder for chem3
scalarEncoder = RandomDistributedScalarEncoder(
enParams["chem3"]['resolution'])
#scalar encoder for chem4
scalarEncoder = RandomDistributedScalarEncoder(
enParams["chem4"]['resolution'])
#encodes scent as a category
categoryEncoder = CategoryEncoder(w=enParams['scent']['w'],categoryList=enParams['scent']['categoryList'],\
                                      forced=enParams['scent']['forced'])

# %%
#encode width for full input encoding 

scent_width = 50*scalarEncoder.getWidth()
    
encodingWidth = (scent_width
                 + categoryEncoder.getWidth())

# %%
sp = SpatialPooler(
  # How large the input encoding will be.
  inputDimensions=(encodingWidth),
  # How many mini-columns will be in the Spatial Pooler.
  columnDimensions=(2025),
  # What percent of the columns's receptive field is available for potential
  # synapses?
  potentialPct=0.85,
  # This means that the input space has no topology.
  globalInhibition=True,
  localAreaDensity=-1.0,
  # Roughly 2%, giving that there is only one inhibition area because we have
  # turned on globalInhibition (40 / 2048 = 0.0195)
  numActiveColumnsPerInhArea=40.0,
  # How quickly synapses grow and degrade.
  synPermInactiveDec=0.005,
  synPermActiveInc=0.04,
  synPermConnected=0.1,
  # boostStrength controls the strength of boosting. Boosting encourages
  # efficient usage of SP columns.
  boostStrength=3.0,
  # Random number generator seed.
  seed=1956,
  # Determines if inputs at the beginning and end of an input dimension should
  # be considered neighbors when mapping columns to inputs.
  wrapAround=False
)

# %%
ArrayOfColumns = numpy.zeros((2025), dtype="int")
activeDutyCycles = numpy.zeros((2025), dtype="float")


#create SDR classifier instance
classifier = SDRClassifierFactory.create(steps=[0])

# %%
plt.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
lemon = []
flower = []
dog = []
sugar = []
frog = []
ladyfly = []
shock = []
apple = []
cat = []

# %%
numRecords = 1000
with open(_INPUT_FILE_PATH, "r") as fin:
    reader = csv.reader(fin)
    headers = reader.next()
    reader.next()
    reader.next()

    for count, record in enumerate(reader):
        
    
        if count >= numRecords: break
            

        # Convert data string into Python date object.
        #dateString = datetime.datetime.strptime(record[1], "%m/%d/%y %H:%M")
        scentString = record[0]
        # Convert data value string into float.
        scent = categoryEncoder.encode(record[0])
        chem1 = float(record[1])
        chem2 = float(record[2])
        chem3 = float(record[3])
        chem4 = float(record[4])
        chem5 = float(record[5])
        chem6 = float(record[6])
        chem7 = float(record[7])
        chem8 = float(record[8])
        chem9 = float(record[9])
        chem10 = float(record[10])
        chem11 = float(record[11])
        chem12 = float(record[12])
        chem13 = float(record[13])
        chem14 = float(record[14])
        chem15 = float(record[15])
        chem16 = float(record[16])
        chem17 = float(record[17])
        chem18 = float(record[18])
        chem19 = float(record[19])
        chem20 = float(record[20])
        chem21 = float(record[21])
        chem22 = float(record[22])
        chem23 = float(record[23])
        chem24 = float(record[24])
        chem25 = float(record[25])
        chem26 = float(record[26])
        chem27 = float(record[27])
        chem28 = float(record[28])
        chem29 = float(record[29])
        chem30 = float(record[30])
        chem31 = float(record[31])
        chem32 = float(record[32])
        chem33 = float(record[33])
        chem34 = float(record[34])
        chem35 = float(record[35])
        chem36 = float(record[36])
        chem37 = float(record[37])
        chem38 = float(record[38])
        chem39 = float(record[39])
        chem40 = float(record[40])
        chem41 = float(record[41])
        chem42 = float(record[42])
        chem43 = float(record[43])
        chem44 = float(record[44])
        chem45 = float(record[45])
        chem46 = float(record[46])
        chem47 = float(record[47])
        chem48 = float(record[48])
        chem49 = float(record[49])
        chem50 = float(record[50])
        dopa = int(record[51])
        

        # To encode, we need to provide zero-filled numpy arrays for the encoders
        # to populate.
        #timeOfDayBits = numpy.zeros(timeOfDayEncoder.getWidth())
        #weekendBits = numpy.zeros(weekendEncoder.getWidth())
        scentBits = numpy.zeros(categoryEncoder.getWidth())
        chem1Bits = numpy.zeros(scalarEncoder.getWidth())
        chem2Bits = numpy.zeros(scalarEncoder.getWidth())
        chem3Bits = numpy.zeros(scalarEncoder.getWidth())
        chem4Bits = numpy.zeros(scalarEncoder.getWidth())
        chem5Bits = numpy.zeros(scalarEncoder.getWidth())
        chem6Bits = numpy.zeros(scalarEncoder.getWidth())
        chem7Bits = numpy.zeros(scalarEncoder.getWidth())
        chem8Bits = numpy.zeros(scalarEncoder.getWidth())
        chem9Bits = numpy.zeros(scalarEncoder.getWidth())
        chem10Bits = numpy.zeros(scalarEncoder.getWidth())
        chem11Bits = numpy.zeros(scalarEncoder.getWidth())
        chem12Bits = numpy.zeros(scalarEncoder.getWidth())
        chem13Bits = numpy.zeros(scalarEncoder.getWidth())
        chem14Bits = numpy.zeros(scalarEncoder.getWidth())
        chem15Bits = numpy.zeros(scalarEncoder.getWidth())
        chem16Bits = numpy.zeros(scalarEncoder.getWidth())
        chem17Bits = numpy.zeros(scalarEncoder.getWidth())
        chem18Bits = numpy.zeros(scalarEncoder.getWidth())
        chem19Bits = numpy.zeros(scalarEncoder.getWidth())
        chem20Bits = numpy.zeros(scalarEncoder.getWidth())
        chem21Bits = numpy.zeros(scalarEncoder.getWidth())
        chem22Bits = numpy.zeros(scalarEncoder.getWidth())
        chem23Bits = numpy.zeros(scalarEncoder.getWidth())
        chem24Bits = numpy.zeros(scalarEncoder.getWidth())
        chem25Bits = numpy.zeros(scalarEncoder.getWidth())
        chem26Bits = numpy.zeros(scalarEncoder.getWidth())
        chem27Bits = numpy.zeros(scalarEncoder.getWidth())
        chem28Bits = numpy.zeros(scalarEncoder.getWidth())
        chem29Bits = numpy.zeros(scalarEncoder.getWidth())
        chem30Bits = numpy.zeros(scalarEncoder.getWidth())
        chem31Bits = numpy.zeros(scalarEncoder.getWidth())
        chem32Bits = numpy.zeros(scalarEncoder.getWidth())
        chem33Bits = numpy.zeros(scalarEncoder.getWidth())
        chem34Bits = numpy.zeros(scalarEncoder.getWidth())
        chem35Bits = numpy.zeros(scalarEncoder.getWidth())
        chem36Bits = numpy.zeros(scalarEncoder.getWidth())
        chem37Bits = numpy.zeros(scalarEncoder.getWidth())
        chem38Bits = numpy.zeros(scalarEncoder.getWidth())
        chem39Bits = numpy.zeros(scalarEncoder.getWidth())
        chem40Bits = numpy.zeros(scalarEncoder.getWidth())
        chem41Bits = numpy.zeros(scalarEncoder.getWidth())
        chem42Bits = numpy.zeros(scalarEncoder.getWidth())
        chem43Bits = numpy.zeros(scalarEncoder.getWidth())
        chem44Bits = numpy.zeros(scalarEncoder.getWidth())
        chem45Bits = numpy.zeros(scalarEncoder.getWidth())
        chem46Bits = numpy.zeros(scalarEncoder.getWidth())
        chem47Bits = numpy.zeros(scalarEncoder.getWidth())
        chem48Bits = numpy.zeros(scalarEncoder.getWidth())
        chem49Bits = numpy.zeros(scalarEncoder.getWidth())
        chem50Bits = numpy.zeros(scalarEncoder.getWidth())
        
        
        
        
            

        # Now we call the encoders to create bit representations for each value.
        #timeOfDayEncoder.encodeIntoArray(dateString, timeOfDayBits)
        #weekendEncoder.encodeIntoArray(dateString, weekendBits)
        categoryEncoder.encodeIntoArray(scentString,scentBits)
        scalarEncoder.encodeIntoArray(chem1, chem1Bits)
        scalarEncoder.encodeIntoArray(chem2, chem2Bits)
        scalarEncoder.encodeIntoArray(chem3, chem3Bits)
        scalarEncoder.encodeIntoArray(chem4, chem4Bits)
        scalarEncoder.encodeIntoArray(chem5, chem5Bits)
        scalarEncoder.encodeIntoArray(chem6, chem6Bits)
        scalarEncoder.encodeIntoArray(chem7, chem7Bits)
        scalarEncoder.encodeIntoArray(chem8, chem8Bits)
        scalarEncoder.encodeIntoArray(chem9, chem9Bits)
        scalarEncoder.encodeIntoArray(chem10, chem10Bits)
        scalarEncoder.encodeIntoArray(chem11, chem11Bits)
        scalarEncoder.encodeIntoArray(chem12, chem12Bits)
        scalarEncoder.encodeIntoArray(chem13, chem13Bits)
        scalarEncoder.encodeIntoArray(chem14, chem14Bits)
        scalarEncoder.encodeIntoArray(chem15, chem15Bits)
        scalarEncoder.encodeIntoArray(chem16, chem16Bits)
        scalarEncoder.encodeIntoArray(chem17, chem17Bits)
        scalarEncoder.encodeIntoArray(chem18, chem18Bits)
        scalarEncoder.encodeIntoArray(chem19, chem19Bits)
        scalarEncoder.encodeIntoArray(chem20, chem20Bits)
        scalarEncoder.encodeIntoArray(chem21, chem21Bits)
        scalarEncoder.encodeIntoArray(chem22, chem22Bits)
        scalarEncoder.encodeIntoArray(chem23, chem23Bits)
        scalarEncoder.encodeIntoArray(chem24, chem24Bits)
        scalarEncoder.encodeIntoArray(chem25, chem25Bits)
        scalarEncoder.encodeIntoArray(chem26, chem26Bits)
        scalarEncoder.encodeIntoArray(chem27, chem27Bits)
        scalarEncoder.encodeIntoArray(chem28, chem28Bits)
        scalarEncoder.encodeIntoArray(chem29, chem29Bits)
        scalarEncoder.encodeIntoArray(chem30, chem30Bits)
        scalarEncoder.encodeIntoArray(chem31, chem31Bits)
        scalarEncoder.encodeIntoArray(chem32, chem32Bits)
        scalarEncoder.encodeIntoArray(chem33, chem33Bits)
        scalarEncoder.encodeIntoArray(chem34, chem34Bits)
        scalarEncoder.encodeIntoArray(chem35, chem35Bits)
        scalarEncoder.encodeIntoArray(chem36, chem36Bits)
        scalarEncoder.encodeIntoArray(chem37, chem37Bits)
        scalarEncoder.encodeIntoArray(chem38, chem38Bits)
        scalarEncoder.encodeIntoArray(chem39, chem39Bits)
        scalarEncoder.encodeIntoArray(chem40, chem40Bits)
        scalarEncoder.encodeIntoArray(chem41, chem41Bits)
        scalarEncoder.encodeIntoArray(chem42, chem42Bits)
        scalarEncoder.encodeIntoArray(chem43, chem43Bits)
        scalarEncoder.encodeIntoArray(chem44, chem44Bits)
        scalarEncoder.encodeIntoArray(chem45, chem45Bits)
        scalarEncoder.encodeIntoArray(chem46, chem46Bits)
        scalarEncoder.encodeIntoArray(chem47, chem47Bits)
        scalarEncoder.encodeIntoArray(chem48, chem48Bits)
        scalarEncoder.encodeIntoArray(chem49, chem49Bits)
        scalarEncoder.encodeIntoArray(chem50, chem50Bits)
        
        
        
       

        # Concatenate all these encodings into one large encoding for Spatial
        # Pooling.
            
        encoding = numpy.concatenate(
        [scentBits, chem1Bits, chem2Bits, chem3Bits, chem4Bits,\
        chem5Bits, chem6Bits, chem7Bits, chem8Bits, chem9Bits,\
        chem10Bits, chem11Bits, chem12Bits, chem13Bits, chem14Bits, chem15Bits, chem16Bits, chem17Bits,\
        chem18Bits, chem19Bits, chem20Bits, chem21Bits, chem22Bits, chem23Bits, chem24Bits, chem25Bits,\
        chem26Bits, chem27Bits, chem28Bits, chem29Bits, chem30Bits, chem31Bits, chem32Bits, chem33Bits,\
        chem34Bits, chem35Bits, chem36Bits, chem37Bits, chem38Bits, chem39Bits, chem40Bits, chem41Bits,\
        chem42Bits, chem43Bits, chem44Bits, chem45Bits, chem46Bits, chem47Bits, chem48Bits, chem49Bits, chem50Bits]
        )
        numpy.set_printoptions(threshold=numpy.inf)
        
      
        
        
        # Get the bucket info for this input value for classification.
        bucketIdx = categoryEncoder.getBucketIndices(scentString)[0]
        #use dopa value to learn scent n times in a row before learning next scent
        
        for i in range(dopa):
            
            
            sp.compute(encoding, learn=True, activeArray=ArrayOfColumns)
            
            #active column indices 
        
            sp.getActiveDutyCycles(activeDutyCycles)
        
       
        
        
            activeColumnIndices = numpy.nonzero(ArrayOfColumns)[0]
       
    
            #Heatmap of columns 
            #array = numpy.reshape(activeDutyCycles, (45,45))
        
        
            #plt.imshow(array, cmap='hot', interpolation='nearest')
    
            #plt.show()
        
        

        
        # Run classifier to translate active cells back to scalar value.
            classifierResult = classifier.compute(
          recordNum=count,
          patternNZ=activeColumnIndices,
          classification={
        "bucketIdx": bucketIdx,
        "actValue": record[0]
          },
          learn=True,
          infer=True
            )

        # Print the best prediction for 0 steps out.
            probability, value = sorted(
          zip(classifierResult[0], classifierResult["actualValues"]),
        reverse=True
        )[0]
        
        
        
        #print("1-step: {:16} ({:4.4}%)".format(value, probability * 100))
        print "Actual Value: {} Prediction of: {} has probability of {}.".format(record[0], value, probability*100.0)
# Out:
# Actual Value: ladyfly Prediction of: ladyfly has probability of 100.0.
# Actual Value: apple Prediction of: apple has probability of 100.0.
# Actual Value: cat Prediction of: cat has probability of 100.0.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 100.0.
# Actual Value: flower Prediction of: ladyfly has probability of 100.0.
# Actual Value: flower Prediction of: flower has probability of 2.36913304614.
# Actual Value: frog Prediction of: frog has probability of 5.48758634681.
# Actual Value: dog Prediction of: flower has probability of 2.34839886124.
# Actual Value: cat Prediction of: cat has probability of 1.98232667807.
# Actual Value: dog Prediction of: dog has probability of 1.6024896138.
# Actual Value: shock Prediction of: shock has probability of 3.66354266644.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 2.00736297225.
# Actual Value: apple Prediction of: apple has probability of 7.78516589161.
# Actual Value: sugar Prediction of: sugar has probability of 5.64113041766.
# Actual Value: lemon Prediction of: flower has probability of 1.18446461885.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 1.50195524314.
# Actual Value: dog Prediction of: sugar has probability of 1.40659370785.
# Actual Value: sugar Prediction of: sugar has probability of 5.98324894903.
# Actual Value: flower Prediction of: ladyfly has probability of 1.46091873496.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 1.91966068312.
# Actual Value: frog Prediction of: frog has probability of 13.1889496155.
# Actual Value: frog Prediction of: frog has probability of 12.8241263339.
# Actual Value: dog Prediction of: frog has probability of 1.46089020735.
# Actual Value: lemon Prediction of: lemon has probability of 1.22103223518.
# Actual Value: flower Prediction of: frog has probability of 1.39351950891.
# Actual Value: shock Prediction of: shock has probability of 25.1248761708.
# Actual Value: frog Prediction of: frog has probability of 8.17213334603.
# Actual Value: apple Prediction of: apple has probability of 30.2325533742.
# Actual Value: frog Prediction of: frog has probability of 63.8033489037.
# Actual Value: lemon Prediction of: sugar has probability of 1.4563285955.
# Actual Value: apple Prediction of: apple has probability of 19.5631002595.
# Actual Value: cat Prediction of: cat has probability of 2.52836832016.
# Actual Value: sugar Prediction of: sugar has probability of 69.5434794931.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 22.5962366615.
# Actual Value: flower Prediction of: ladyfly has probability of 1.46000523006.
# Actual Value: flower Prediction of: ladyfly has probability of 1.45910188313.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 32.7993820915.
# Actual Value: shock Prediction of: shock has probability of 65.0915688646.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 39.1800444705.
# Actual Value: apple Prediction of: apple has probability of 77.3049463705.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 44.3673603159.
# Actual Value: dog Prediction of: ladyfly has probability of 1.39124819968.
# Actual Value: sugar Prediction of: sugar has probability of 49.1673282015.
# Actual Value: frog Prediction of: frog has probability of 37.2175864092.
# Actual Value: lemon Prediction of: frog has probability of 1.56947798835.
# Actual Value: shock Prediction of: shock has probability of 37.4990733641.
# Actual Value: frog Prediction of: frog has probability of 68.1839149986.
# Actual Value: frog Prediction of: frog has probability of 48.6157269552.
# Actual Value: apple Prediction of: apple has probability of 41.3482761582.
# Actual Value: cat Prediction of: cat has probability of 3.89783423809.
# Actual Value: dog Prediction of: cat has probability of 1.60357616984.
# Actual Value: flower Prediction of: cat has probability of 1.54800789035.
# Actual Value: sugar Prediction of: sugar has probability of 48.9163282263.
# Actual Value: shock Prediction of: shock has probability of 84.3154953501.
# Actual Value: sugar Prediction of: sugar has probability of 31.0372693106.
# Actual Value: dog Prediction of: shock has probability of 2.28300999454.
# Actual Value: shock Prediction of: shock has probability of 44.8243672636.
# Actual Value: cat Prediction of: cat has probability of 16.0859753254.
# Actual Value: apple Prediction of: apple has probability of 58.6976235698.
# Actual Value: apple Prediction of: apple has probability of 23.8456780851.
# Actual Value: flower Prediction of: apple has probability of 1.63677008723.
# Actual Value: cat Prediction of: cat has probability of 9.76390281832.
# Actual Value: dog Prediction of: cat has probability of 1.71603666138.
# Actual Value: lemon Prediction of: cat has probability of 1.39977985286.
# Actual Value: flower Prediction of: cat has probability of 1.64994435366.
# Actual Value: lemon Prediction of: lemon has probability of 1.40130108714.
# Actual Value: sugar Prediction of: sugar has probability of 67.2743068574.
# Actual Value: cat Prediction of: cat has probability of 30.35240312.
# Actual Value: apple Prediction of: apple has probability of 16.2449275952.
# Actual Value: flower Prediction of: apple has probability of 2.31975777609.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 66.2279446603.
# Actual Value: dog Prediction of: ladyfly has probability of 2.87180420337.
# Actual Value: frog Prediction of: frog has probability of 87.349679316.
# Actual Value: shock Prediction of: shock has probability of 90.4065913504.
# Actual Value: dog Prediction of: shock has probability of 2.153627437.
# Actual Value: flower Prediction of: shock has probability of 1.67441994891.
# Actual Value: apple Prediction of: apple has probability of 87.7332942346.
# Actual Value: sugar Prediction of: sugar has probability of 41.9160643024.
# Actual Value: cat Prediction of: cat has probability of 36.0613958009.
# Actual Value: apple Prediction of: apple has probability of 29.9622346293.
# Actual Value: dog Prediction of: apple has probability of 2.98229485992.
# Actual Value: lemon Prediction of: apple has probability of 1.86220035735.
# Actual Value: lemon Prediction of: apple has probability of 1.83871207628.
# Actual Value: dog Prediction of: apple has probability of 2.97827239525.
# Actual Value: shock Prediction of: shock has probability of 82.971656773.
# Actual Value: flower Prediction of: shock has probability of 2.37199746136.
# Actual Value: apple Prediction of: apple has probability of 32.1007114128.
# Actual Value: dog Prediction of: apple has probability of 2.98557613417.
# Actual Value: apple Prediction of: apple has probability of 37.3420795788.
# Actual Value: dog Prediction of: apple has probability of 2.98476314821.
# Actual Value: dog Prediction of: apple has probability of 2.97856875583.
# Actual Value: shock Prediction of: shock has probability of 79.9923212821.
# Actual Value: apple Prediction of: apple has probability of 42.543389466.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 59.1937252195.
# Actual Value: shock Prediction of: shock has probability of 54.7695238783.
# Actual Value: frog Prediction of: frog has probability of 82.916956012.
# Actual Value: sugar Prediction of: sugar has probability of 89.5941403763.
# Actual Value: sugar Prediction of: sugar has probability of 89.1800000855.
# Actual Value: shock Prediction of: shock has probability of 90.6183699909.
# Actual Value: dog Prediction of: shock has probability of 2.77772519235.
# Actual Value: flower Prediction of: shock has probability of 2.00378602219.
# Actual Value: shock Prediction of: shock has probability of 64.461912172.
# Actual Value: lemon Prediction of: shock has probability of 1.71540315147.
# Actual Value: shock Prediction of: shock has probability of 91.3254233427.
# Actual Value: frog Prediction of: frog has probability of 91.7382839331.
# Actual Value: lemon Prediction of: frog has probability of 1.7526911623.
# Actual Value: cat Prediction of: cat has probability of 16.8789830151.
# Actual Value: dog Prediction of: cat has probability of 2.60277396022.
# Actual Value: flower Prediction of: cat has probability of 1.90817688332.
# Actual Value: shock Prediction of: shock has probability of 85.7389626047.
# Actual Value: sugar Prediction of: sugar has probability of 70.1515068487.
# Actual Value: shock Prediction of: shock has probability of 62.1807017364.
# Actual Value: shock Prediction of: shock has probability of 15.9501040592.
# Actual Value: lemon Prediction of: shock has probability of 1.78679697709.
# Actual Value: cat Prediction of: cat has probability of 22.5181797286.
# Actual Value: cat Prediction of: cat has probability of 24.5995884612.
# Actual Value: frog Prediction of: frog has probability of 90.382047499.
# Actual Value: flower Prediction of: flower has probability of 1.7240556588.
# Actual Value: sugar Prediction of: sugar has probability of 44.0745293126.
# Actual Value: shock Prediction of: shock has probability of 79.1675861923.
# Actual Value: flower Prediction of: shock has probability of 2.42648140345.
# Actual Value: lemon Prediction of: lemon has probability of 1.72546852842.
# Actual Value: lemon Prediction of: lemon has probability of 1.78750106948.
# Actual Value: sugar Prediction of: sugar has probability of 48.0416974702.
# Actual Value: sugar Prediction of: sugar has probability of 37.0767446735.
# Actual Value: flower Prediction of: shock has probability of 4.2754350972.
# Actual Value: lemon Prediction of: lemon has probability of 1.86009549968.
# Actual Value: flower Prediction of: shock has probability of 4.13384468429.
# Actual Value: lemon Prediction of: lemon has probability of 1.92667819001.
# Actual Value: dog Prediction of: shock has probability of 4.86804346411.
# Actual Value: frog Prediction of: frog has probability of 91.8044714048.
# Actual Value: sugar Prediction of: sugar has probability of 77.4405790499.
# Actual Value: apple Prediction of: apple has probability of 98.13586682.
# Actual Value: apple Prediction of: apple has probability of 83.2679652593.
# Actual Value: dog Prediction of: apple has probability of 2.7558190453.
# Actual Value: sugar Prediction of: sugar has probability of 42.5736909116.
# Actual Value: lemon Prediction of: lemon has probability of 2.00469719012.
# Actual Value: lemon Prediction of: lemon has probability of 2.07804109893.
# Actual Value: lemon Prediction of: lemon has probability of 2.15815709981.
# Actual Value: cat Prediction of: cat has probability of 68.6948553189.
# Actual Value: shock Prediction of: shock has probability of 89.5959500071.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 65.8222775372.
# Actual Value: cat Prediction of: cat has probability of 64.8318971267.
# Actual Value: lemon Prediction of: lemon has probability of 2.20343163567.
# Actual Value: cat Prediction of: cat has probability of 60.1429456401.
# Actual Value: flower Prediction of: cat has probability of 2.83802452056.
# Actual Value: lemon Prediction of: lemon has probability of 2.2568282233.
# Actual Value: flower Prediction of: cat has probability of 2.83412754163.
# Actual Value: frog Prediction of: frog has probability of 95.438978693.
# Actual Value: shock Prediction of: shock has probability of 87.5010568254.
# Actual Value: frog Prediction of: frog has probability of 85.8982206335.
# Actual Value: flower Prediction of: flower has probability of 2.10144065638.
# Actual Value: sugar Prediction of: sugar has probability of 69.0127226384.
# Actual Value: lemon Prediction of: lemon has probability of 2.35190446021.
# Actual Value: cat Prediction of: cat has probability of 70.348215158.
# Actual Value: cat Prediction of: cat has probability of 60.2998448023.
# Actual Value: apple Prediction of: apple has probability of 95.2458988529.
# Actual Value: shock Prediction of: shock has probability of 73.9382163424.
# Actual Value: frog Prediction of: frog has probability of 94.2058271819.
# Actual Value: sugar Prediction of: sugar has probability of 96.727896442.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 81.1962716855.
# Actual Value: lemon Prediction of: lemon has probability of 2.44096436156.
# Actual Value: flower Prediction of: ladyfly has probability of 2.35542200608.
# Actual Value: sugar Prediction of: sugar has probability of 16.360473724.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 84.3238906128.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 89.1932623771.
# Actual Value: apple Prediction of: apple has probability of 71.9330334926.
# Actual Value: shock Prediction of: shock has probability of 89.7797849623.
# Actual Value: dog Prediction of: shock has probability of 3.01909436601.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 51.8840916064.
# Actual Value: dog Prediction of: ladyfly has probability of 4.31430160261.
# Actual Value: lemon Prediction of: lemon has probability of 2.52849887796.
# Actual Value: apple Prediction of: apple has probability of 97.1362175461.
# Actual Value: flower Prediction of: flower has probability of 2.28133394313.
# Actual Value: dog Prediction of: apple has probability of 3.46648101462.
# Actual Value: frog Prediction of: frog has probability of 95.9561061678.
# Actual Value: shock Prediction of: shock has probability of 70.2347247927.
# Actual Value: apple Prediction of: apple has probability of 25.8346709873.
# Actual Value: lemon Prediction of: lemon has probability of 2.63617536517.
# Actual Value: flower Prediction of: flower has probability of 2.36316240689.
# Actual Value: frog Prediction of: frog has probability of 96.2246146559.
# Actual Value: shock Prediction of: shock has probability of 85.1505519635.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 69.5947281721.
# Actual Value: apple Prediction of: apple has probability of 92.2860635397.
# Actual Value: flower Prediction of: flower has probability of 2.37375167607.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 64.4284367726.
# Actual Value: frog Prediction of: frog has probability of 78.5080344957.
# Actual Value: dog Prediction of: dog has probability of 2.3125225444.
# Actual Value: cat Prediction of: cat has probability of 23.2448648849.
# Actual Value: flower Prediction of: flower has probability of 2.46789619941.
# Actual Value: cat Prediction of: cat has probability of 30.8182903508.
# Actual Value: flower Prediction of: flower has probability of 2.51661930821.
# Actual Value: apple Prediction of: apple has probability of 69.685159262.
# Actual Value: frog Prediction of: frog has probability of 90.9938194008.
# Actual Value: apple Prediction of: apple has probability of 90.1445388111.
# Actual Value: lemon Prediction of: sugar has probability of 3.59427874789.
# Actual Value: frog Prediction of: frog has probability of 96.4671030533.
# Actual Value: flower Prediction of: sugar has probability of 3.45230847512.
# Actual Value: cat Prediction of: cat has probability of 40.3248461886.
# Actual Value: frog Prediction of: frog has probability of 75.6515668001.
# Actual Value: lemon Prediction of: sugar has probability of 3.58633466373.
# Actual Value: dog Prediction of: dog has probability of 2.40128623674.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 54.8694067119.
# Actual Value: dog Prediction of: dog has probability of 2.48572757102.
# Actual Value: frog Prediction of: frog has probability of 83.4461618468.
# Actual Value: flower Prediction of: sugar has probability of 3.45631276435.
# Actual Value: lemon Prediction of: sugar has probability of 3.56912799379.
# Actual Value: frog Prediction of: frog has probability of 92.5330953477.
# Actual Value: dog Prediction of: frog has probability of 2.64992578958.
# Actual Value: frog Prediction of: frog has probability of 95.0847842133.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 70.3894682432.
# Actual Value: lemon Prediction of: sugar has probability of 3.56109334519.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 67.0547670639.
# Actual Value: cat Prediction of: cat has probability of 51.3797310322.
# Actual Value: dog Prediction of: dog has probability of 2.70552630832.
# Actual Value: cat Prediction of: cat has probability of 44.6140514261.
# Actual Value: apple Prediction of: apple has probability of 79.9930011811.
# Actual Value: frog Prediction of: frog has probability of 95.8194742495.
# Actual Value: flower Prediction of: sugar has probability of 3.44692889383.
# Actual Value: shock Prediction of: shock has probability of 86.1450684993.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 73.2043842779.
# Actual Value: shock Prediction of: shock has probability of 97.923163322.
# Actual Value: cat Prediction of: cat has probability of 62.436187717.
# Actual Value: shock Prediction of: shock has probability of 81.4246773712.
# Actual Value: apple Prediction of: apple has probability of 28.4082810513.
# Actual Value: dog Prediction of: apple has probability of 3.02062198168.
# Actual Value: flower Prediction of: sugar has probability of 3.42661608301.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 75.7336072652.
# Actual Value: lemon Prediction of: sugar has probability of 3.56940130597.
# Actual Value: flower Prediction of: flower has probability of 2.94738085436.
# Actual Value: apple Prediction of: apple has probability of 95.5164581484.
# Actual Value: lemon Prediction of: sugar has probability of 3.56127343265.
# Actual Value: sugar Prediction of: sugar has probability of 61.9079748118.
# Actual Value: cat Prediction of: cat has probability of 86.7538982582.
# Actual Value: cat Prediction of: cat has probability of 87.5606115213.
# Actual Value: sugar Prediction of: sugar has probability of 76.1891614691.
# Actual Value: sugar Prediction of: sugar has probability of 86.335939585.
# Actual Value: flower Prediction of: flower has probability of 3.14613739136.
# Actual Value: shock Prediction of: shock has probability of 81.5292603174.
# Actual Value: dog Prediction of: shock has probability of 4.24267498343.
# Actual Value: flower Prediction of: shock has probability of 3.95291450289.
# Actual Value: cat Prediction of: cat has probability of 93.9085087345.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 98.2802076596.
# Actual Value: flower Prediction of: flower has probability of 3.10791985302.
# Actual Value: cat Prediction of: cat has probability of 87.8019369012.
# Actual Value: lemon Prediction of: lemon has probability of 3.37875748009.
# Actual Value: frog Prediction of: frog has probability of 98.8202407083.
# Actual Value: lemon Prediction of: lemon has probability of 3.46522947695.
# Actual Value: shock Prediction of: shock has probability of 89.1282406613.
# Actual Value: dog Prediction of: shock has probability of 3.68238169529.
# Actual Value: cat Prediction of: cat has probability of 86.5235617052.
# Actual Value: flower Prediction of: flower has probability of 3.40110635172.
# Actual Value: apple Prediction of: apple has probability of 99.004451065.
# Actual Value: flower Prediction of: flower has probability of 3.53580429622.
# Actual Value: dog Prediction of: dog has probability of 3.13197366119.
# Actual Value: frog Prediction of: frog has probability of 85.6165091933.
# Actual Value: sugar Prediction of: sugar has probability of 59.3903117425.
# Actual Value: dog Prediction of: frog has probability of 3.68949964554.
# Actual Value: sugar Prediction of: sugar has probability of 63.3072878712.
# Actual Value: dog Prediction of: frog has probability of 3.68063894506.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 97.3052552378.
# Actual Value: flower Prediction of: flower has probability of 3.64849363742.
# Actual Value: sugar Prediction of: sugar has probability of 41.8658443245.
# Actual Value: lemon Prediction of: lemon has probability of 3.56606931745.
# Actual Value: lemon Prediction of: lemon has probability of 3.73683601326.
# Actual Value: shock Prediction of: shock has probability of 88.4421204874.
# Actual Value: cat Prediction of: cat has probability of 94.7348754123.
# Actual Value: shock Prediction of: shock has probability of 86.0697458594.
# Actual Value: dog Prediction of: shock has probability of 6.89797659544.
# Actual Value: cat Prediction of: cat has probability of 89.8998307647.
# Actual Value: apple Prediction of: apple has probability of 99.0990245516.
# Actual Value: apple Prediction of: apple has probability of 36.3995420536.
# Actual Value: sugar Prediction of: sugar has probability of 90.844044679.
# Actual Value: flower Prediction of: flower has probability of 3.72612156178.
# Actual Value: frog Prediction of: frog has probability of 99.2002919589.
# Actual Value: shock Prediction of: shock has probability of 93.712460637.
# Actual Value: sugar Prediction of: sugar has probability of 84.008034213.
# Actual Value: dog Prediction of: shock has probability of 3.69122614553.
# Actual Value: dog Prediction of: shock has probability of 3.78193044003.
# Actual Value: cat Prediction of: cat has probability of 94.3368674578.
# Actual Value: flower Prediction of: flower has probability of 3.88243576312.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 95.1784371101.
# Actual Value: frog Prediction of: frog has probability of 83.3278575337.
# Actual Value: cat Prediction of: cat has probability of 90.6912373086.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 94.4187825986.
# Actual Value: lemon Prediction of: lemon has probability of 3.85887459244.
# Actual Value: sugar Prediction of: sugar has probability of 84.5723056287.
# Actual Value: flower Prediction of: flower has probability of 3.95686176952.
# Actual Value: dog Prediction of: dog has probability of 3.7584778247.
# Actual Value: frog Prediction of: frog has probability of 73.1754101812.
# Actual Value: sugar Prediction of: sugar has probability of 80.0857262234.
# Actual Value: shock Prediction of: shock has probability of 80.0113149069.
# Actual Value: shock Prediction of: shock has probability of 96.7914360974.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 97.6452773831.
# Actual Value: apple Prediction of: apple has probability of 99.1435243099.
# Actual Value: lemon Prediction of: lemon has probability of 4.03640316804.
# Actual Value: frog Prediction of: frog has probability of 98.6992573453.
# Actual Value: cat Prediction of: cat has probability of 90.9168807398.
# Actual Value: dog Prediction of: dog has probability of 3.83003597805.
# Actual Value: cat Prediction of: cat has probability of 89.9846806904.
# Actual Value: apple Prediction of: apple has probability of 60.5946947264.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 76.4464187003.
# Actual Value: cat Prediction of: cat has probability of 89.1957343448.
# Actual Value: dog Prediction of: dog has probability of 3.94912678165.
# Actual Value: flower Prediction of: flower has probability of 4.31247684383.
# Actual Value: flower Prediction of: flower has probability of 4.46687654504.
# Actual Value: apple Prediction of: apple has probability of 97.2079796336.
# Actual Value: sugar Prediction of: sugar has probability of 89.6370554736.
# Actual Value: shock Prediction of: shock has probability of 78.9715380121.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 96.8929191039.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 90.7336726414.
# Actual Value: dog Prediction of: ladyfly has probability of 4.39295411223.
# Actual Value: shock Prediction of: shock has probability of 91.795256526.
# Actual Value: shock Prediction of: shock has probability of 90.1370264893.
# Actual Value: flower Prediction of: flower has probability of 4.23032209432.
# Actual Value: dog Prediction of: shock has probability of 5.54192204534.
# Actual Value: sugar Prediction of: sugar has probability of 94.7056695165.
# Actual Value: shock Prediction of: shock has probability of 81.4676221808.
# Actual Value: sugar Prediction of: sugar has probability of 98.3985780384.
# Actual Value: apple Prediction of: apple has probability of 99.2401294996.
# Actual Value: sugar Prediction of: sugar has probability of 94.4290132554.
# Actual Value: dog Prediction of: apple has probability of 5.53259274261.
# Actual Value: flower Prediction of: flower has probability of 4.34806808094.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 97.7868282234.
# Actual Value: shock Prediction of: shock has probability of 70.7981199079.
# Actual Value: shock Prediction of: shock has probability of 67.0089468505.
# Actual Value: apple Prediction of: apple has probability of 57.9515204229.
# Actual Value: lemon Prediction of: lemon has probability of 4.05778166772.
# Actual Value: cat Prediction of: cat has probability of 88.7323551675.
# Actual Value: flower Prediction of: flower has probability of 4.70869760156.
# Actual Value: shock Prediction of: shock has probability of 96.5050267853.
# Actual Value: flower Prediction of: flower has probability of 4.91063516175.
# Actual Value: lemon Prediction of: lemon has probability of 4.20790390229.
# Actual Value: cat Prediction of: cat has probability of 80.6779991651.
# Actual Value: sugar Prediction of: sugar has probability of 95.6971608893.
# Actual Value: dog Prediction of: cat has probability of 5.60551818903.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 97.3198076772.
# Actual Value: flower Prediction of: flower has probability of 4.79682272646.
# Actual Value: apple Prediction of: apple has probability of 27.8666480624.
# Actual Value: flower Prediction of: flower has probability of 4.83915148139.
# Actual Value: flower Prediction of: flower has probability of 5.20252638195.
# Actual Value: lemon Prediction of: lemon has probability of 4.36558596227.
# Actual Value: cat Prediction of: cat has probability of 89.8146297011.
# Actual Value: frog Prediction of: frog has probability of 94.1427501866.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 91.3493678546.
# Actual Value: frog Prediction of: frog has probability of 97.7652139702.
# Actual Value: cat Prediction of: cat has probability of 80.6035263681.
# Actual Value: lemon Prediction of: lemon has probability of 4.58389620801.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 85.9640632126.
# Actual Value: shock Prediction of: shock has probability of 89.2853158565.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 93.6776867531.
# Actual Value: sugar Prediction of: sugar has probability of 84.8639961306.
# Actual Value: flower Prediction of: flower has probability of 5.20616746986.
# Actual Value: apple Prediction of: apple has probability of 95.2470960027.
# Actual Value: frog Prediction of: frog has probability of 98.7781041811.
# Actual Value: lemon Prediction of: lemon has probability of 4.75553060561.
# Actual Value: shock Prediction of: shock has probability of 94.0214244616.
# Actual Value: shock Prediction of: shock has probability of 95.5964961447.
# Actual Value: cat Prediction of: cat has probability of 77.3470262187.
# Actual Value: apple Prediction of: apple has probability of 84.8317190436.
# Actual Value: lemon Prediction of: lemon has probability of 4.8386161991.
# Actual Value: shock Prediction of: shock has probability of 91.8891675702.
# Actual Value: apple Prediction of: apple has probability of 57.0317131615.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 90.9735968134.
# Actual Value: shock Prediction of: shock has probability of 93.9959575391.
# Actual Value: lemon Prediction of: lemon has probability of 4.66797162494.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 86.5011817797.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 77.7477907344.
# Actual Value: sugar Prediction of: sugar has probability of 93.6925738835.
# Actual Value: lemon Prediction of: lemon has probability of 5.1723135404.
# Actual Value: lemon Prediction of: lemon has probability of 5.32601971958.
# Actual Value: dog Prediction of: dog has probability of 4.60677463692.
# Actual Value: shock Prediction of: shock has probability of 95.0676069818.
# Actual Value: cat Prediction of: cat has probability of 92.9789038706.
# Actual Value: shock Prediction of: shock has probability of 85.3456537358.
# Actual Value: shock Prediction of: shock has probability of 78.1768519001.
# Actual Value: sugar Prediction of: sugar has probability of 85.1545241369.
# Actual Value: apple Prediction of: apple has probability of 99.273723032.
# Actual Value: flower Prediction of: flower has probability of 5.72619564504.
# Actual Value: cat Prediction of: cat has probability of 92.3919435077.
# Actual Value: sugar Prediction of: sugar has probability of 77.3387738894.
# Actual Value: apple Prediction of: apple has probability of 97.4686970366.
# Actual Value: dog Prediction of: dog has probability of 4.7645624358.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 98.3479648561.
# Actual Value: frog Prediction of: frog has probability of 98.3219391824.
# Actual Value: cat Prediction of: cat has probability of 90.0131391023.
# Actual Value: shock Prediction of: shock has probability of 89.8677350532.
# Actual Value: lemon Prediction of: lemon has probability of 5.68107165046.
# Actual Value: apple Prediction of: apple has probability of 55.8392156633.
# Actual Value: cat Prediction of: cat has probability of 84.4709602612.
# Actual Value: flower Prediction of: flower has probability of 6.00760699026.
# Actual Value: frog Prediction of: frog has probability of 93.8307047564.
# Actual Value: flower Prediction of: flower has probability of 5.63044782677.
# Actual Value: sugar Prediction of: sugar has probability of 78.0496765318.
# Actual Value: cat Prediction of: cat has probability of 95.1767268457.
# Actual Value: flower Prediction of: flower has probability of 6.0151630165.
# Actual Value: cat Prediction of: cat has probability of 96.2010980165.
# Actual Value: flower Prediction of: flower has probability of 6.63162229063.
# Actual Value: cat Prediction of: cat has probability of 95.9625590884.
# Actual Value: shock Prediction of: shock has probability of 95.0916794463.
# Actual Value: dog Prediction of: dog has probability of 5.01415731478.
# Actual Value: sugar Prediction of: sugar has probability of 9.57043557211.
# Actual Value: frog Prediction of: frog has probability of 95.4119700415.
# Actual Value: dog Prediction of: dog has probability of 5.19122053625.
# Actual Value: cat Prediction of: cat has probability of 94.446119083.
# Actual Value: dog Prediction of: dog has probability of 5.25193042209.
# Actual Value: flower Prediction of: flower has probability of 6.57651668284.
# Actual Value: apple Prediction of: apple has probability of 98.5482290286.
# Actual Value: cat Prediction of: cat has probability of 93.6546857754.
# Actual Value: dog Prediction of: dog has probability of 5.5484101837.
# Actual Value: frog Prediction of: frog has probability of 95.4470588214.
# Actual Value: lemon Prediction of: lemon has probability of 5.49857974251.
# Actual Value: dog Prediction of: dog has probability of 5.76941478109.
# Actual Value: cat Prediction of: cat has probability of 87.2843756932.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 83.9663557085.
# Actual Value: flower Prediction of: flower has probability of 7.19529480101.
# Actual Value: flower Prediction of: flower has probability of 7.4436833278.
# Actual Value: shock Prediction of: shock has probability of 96.5739456157.
# Actual Value: dog Prediction of: dog has probability of 5.93536285482.
# Actual Value: flower Prediction of: flower has probability of 7.11141819105.
# Actual Value: flower Prediction of: flower has probability of 7.33864675761.
# Actual Value: frog Prediction of: frog has probability of 93.0086768085.
# Actual Value: frog Prediction of: frog has probability of 95.145428961.
# Actual Value: flower Prediction of: flower has probability of 7.32650763411.
# Actual Value: lemon Prediction of: lemon has probability of 5.71503590912.
# Actual Value: apple Prediction of: apple has probability of 71.5409417195.
# Actual Value: frog Prediction of: frog has probability of 94.5498905565.
# Actual Value: frog Prediction of: frog has probability of 96.1063952701.
# Actual Value: sugar Prediction of: sugar has probability of 75.3241661594.
# Actual Value: apple Prediction of: apple has probability of 64.4146788518.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 91.1746732718.
# Actual Value: lemon Prediction of: lemon has probability of 6.08463029553.
# Actual Value: sugar Prediction of: sugar has probability of 45.7836499957.
# Actual Value: lemon Prediction of: lemon has probability of 6.28253657726.
# Actual Value: apple Prediction of: apple has probability of 78.4740813603.
# Actual Value: lemon Prediction of: lemon has probability of 6.52183916592.
# Actual Value: apple Prediction of: apple has probability of 16.311702055.
# Actual Value: apple Prediction of: apple has probability of 98.6855381417.
# Actual Value: flower Prediction of: flower has probability of 7.71683430973.
# Actual Value: apple Prediction of: apple has probability of 97.8786709553.
# Actual Value: dog Prediction of: dog has probability of 6.29392412403.
# Actual Value: sugar Prediction of: sugar has probability of 93.2342353159.
# Actual Value: shock Prediction of: shock has probability of 94.1877378889.
# Actual Value: frog Prediction of: frog has probability of 99.1587018989.
# Actual Value: flower Prediction of: flower has probability of 8.41461128564.
# Actual Value: cat Prediction of: cat has probability of 76.6691630275.
# Actual Value: frog Prediction of: frog has probability of 96.4121163629.
# Actual Value: sugar Prediction of: sugar has probability of 88.1560471861.
# Actual Value: shock Prediction of: shock has probability of 97.6473617761.
# Actual Value: frog Prediction of: frog has probability of 98.2746344833.
# Actual Value: dog Prediction of: dog has probability of 6.48136281073.
# Actual Value: flower Prediction of: flower has probability of 8.334060757.
# Actual Value: lemon Prediction of: lemon has probability of 6.57482036315.
# Actual Value: sugar Prediction of: sugar has probability of 96.6715625419.
# Actual Value: shock Prediction of: shock has probability of 99.1810200688.
# Actual Value: flower Prediction of: flower has probability of 8.21100573723.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 98.8775884892.
# Actual Value: sugar Prediction of: sugar has probability of 61.450196338.
# Actual Value: shock Prediction of: shock has probability of 96.7049659331.
# Actual Value: flower Prediction of: flower has probability of 8.28777564095.
# Actual Value: dog Prediction of: dog has probability of 6.22558683414.
# Actual Value: apple Prediction of: apple has probability of 99.6231333992.
# Actual Value: apple Prediction of: apple has probability of 90.9497965186.
# Actual Value: shock Prediction of: shock has probability of 95.3818118945.
# Actual Value: shock Prediction of: shock has probability of 98.9466238432.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 86.3280577478.
# Actual Value: cat Prediction of: cat has probability of 82.9670545681.
# Actual Value: flower Prediction of: flower has probability of 9.0029391682.
# Actual Value: shock Prediction of: shock has probability of 78.52280088.
# Actual Value: shock Prediction of: shock has probability of 81.0183861296.
# Actual Value: cat Prediction of: cat has probability of 88.3553159375.
# Actual Value: flower Prediction of: flower has probability of 8.21877302419.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 94.1007942376.
# Actual Value: frog Prediction of: frog has probability of 96.1615883722.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 89.0852676492.
# Actual Value: shock Prediction of: shock has probability of 98.1169622789.
# Actual Value: shock Prediction of: shock has probability of 95.5976982454.
# Actual Value: shock Prediction of: shock has probability of 80.6593229664.
# Actual Value: flower Prediction of: flower has probability of 9.18294770058.
# Actual Value: dog Prediction of: shock has probability of 6.51580761841.
# Actual Value: flower Prediction of: flower has probability of 9.35844611694.
# Actual Value: shock Prediction of: shock has probability of 76.6337391176.
# Actual Value: dog Prediction of: shock has probability of 8.4176868505.
# Actual Value: dog Prediction of: shock has probability of 8.39638374376.
# Actual Value: cat Prediction of: cat has probability of 85.3173329514.
# Actual Value: lemon Prediction of: lemon has probability of 6.38960119545.
# Actual Value: cat Prediction of: cat has probability of 81.253069979.
# Actual Value: sugar Prediction of: sugar has probability of 79.5865017101.
# Actual Value: cat Prediction of: cat has probability of 86.2481426156.
# Actual Value: apple Prediction of: apple has probability of 99.4051881329.
# Actual Value: frog Prediction of: frog has probability of 98.2983625516.
# Actual Value: frog Prediction of: frog has probability of 97.0846607923.
# Actual Value: dog Prediction of: dog has probability of 7.38026051126.
# Actual Value: flower Prediction of: flower has probability of 10.3115387874.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 93.4474907743.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 92.0898946019.
# Actual Value: dog Prediction of: dog has probability of 7.40401508395.
# Actual Value: cat Prediction of: cat has probability of 94.9371699264.
# Actual Value: frog Prediction of: frog has probability of 99.030113148.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 91.4075986827.
# Actual Value: lemon Prediction of: lemon has probability of 6.20948711598.
# Actual Value: apple Prediction of: apple has probability of 98.5917593585.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 97.3612849209.
# Actual Value: lemon Prediction of: lemon has probability of 6.90151583361.
# Actual Value: shock Prediction of: shock has probability of 93.2761009595.
# Actual Value: apple Prediction of: apple has probability of 44.8772736381.
# Actual Value: cat Prediction of: cat has probability of 82.4488986865.
# Actual Value: apple Prediction of: apple has probability of 98.7286023754.
# Actual Value: apple Prediction of: apple has probability of 96.1843389706.
# Actual Value: dog Prediction of: dog has probability of 7.55920323896.
# Actual Value: cat Prediction of: cat has probability of 83.1127374811.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 92.7040595912.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 96.2072474515.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 77.0203196172.
# Actual Value: flower Prediction of: flower has probability of 9.7785879352.
# Actual Value: apple Prediction of: apple has probability of 86.1228227695.
# Actual Value: cat Prediction of: cat has probability of 77.7353139345.
# Actual Value: frog Prediction of: frog has probability of 98.6125006553.
# Actual Value: cat Prediction of: cat has probability of 77.2620939954.
# Actual Value: apple Prediction of: apple has probability of 97.7029748763.
# Actual Value: frog Prediction of: frog has probability of 96.1498513141.
# Actual Value: frog Prediction of: frog has probability of 90.8502373745.
# Actual Value: sugar Prediction of: sugar has probability of 98.0172116558.
# Actual Value: dog Prediction of: dog has probability of 8.09395109352.
# Actual Value: frog Prediction of: frog has probability of 99.6558075224.
# Actual Value: cat Prediction of: cat has probability of 93.0768950967.
# Actual Value: apple Prediction of: apple has probability of 97.5052525344.
# Actual Value: cat Prediction of: cat has probability of 88.7979861427.
# Actual Value: sugar Prediction of: sugar has probability of 62.2648724978.
# Actual Value: shock Prediction of: shock has probability of 93.2922268008.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 98.8290079662.
# Actual Value: apple Prediction of: apple has probability of 67.8777009661.
# Actual Value: shock Prediction of: shock has probability of 65.9608062429.
# Actual Value: lemon Prediction of: lemon has probability of 7.1845879672.
# Actual Value: shock Prediction of: shock has probability of 72.2084286153.
# Actual Value: lemon Prediction of: lemon has probability of 7.34090046029.
# Actual Value: shock Prediction of: shock has probability of 71.8487243147.
# Actual Value: lemon Prediction of: lemon has probability of 7.57878956957.
# Actual Value: flower Prediction of: flower has probability of 10.8358388377.
# Actual Value: apple Prediction of: apple has probability of 98.8943827469.
# Actual Value: flower Prediction of: flower has probability of 9.86176132929.
# Actual Value: sugar Prediction of: sugar has probability of 58.7605974573.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.289899564.
# Actual Value: sugar Prediction of: sugar has probability of 63.5674565638.
# Actual Value: dog Prediction of: dog has probability of 8.0384802256.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.4266310264.
# Actual Value: dog Prediction of: dog has probability of 8.10114381085.
# Actual Value: apple Prediction of: apple has probability of 99.3027182022.
# Actual Value: flower Prediction of: flower has probability of 11.1409554282.
# Actual Value: dog Prediction of: dog has probability of 8.09762512647.
# Actual Value: frog Prediction of: frog has probability of 99.7441165186.
# Actual Value: shock Prediction of: shock has probability of 91.5448088807.
# Actual Value: sugar Prediction of: sugar has probability of 85.8116819038.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.6568140173.
# Actual Value: flower Prediction of: flower has probability of 11.4430611714.
# Actual Value: cat Prediction of: cat has probability of 98.7557648079.
# Actual Value: dog Prediction of: dog has probability of 8.79494057672.
# Actual Value: flower Prediction of: flower has probability of 12.0103498867.
# Actual Value: flower Prediction of: flower has probability of 12.182340679.
# Actual Value: frog Prediction of: frog has probability of 99.3732377668.
# Actual Value: sugar Prediction of: sugar has probability of 60.6467122168.
# Actual Value: shock Prediction of: shock has probability of 94.0536979757.
# Actual Value: apple Prediction of: apple has probability of 93.5040626355.
# Actual Value: apple Prediction of: apple has probability of 93.8559011693.
# Actual Value: dog Prediction of: dog has probability of 9.35901485813.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.2526242218.
# Actual Value: cat Prediction of: cat has probability of 97.6802794498.
# Actual Value: apple Prediction of: apple has probability of 99.0277070605.
# Actual Value: dog Prediction of: dog has probability of 8.85799040457.
# Actual Value: flower Prediction of: flower has probability of 12.4829564643.
# Actual Value: frog Prediction of: frog has probability of 99.7851320953.
# Actual Value: frog Prediction of: frog has probability of 95.8930750207.
# Actual Value: shock Prediction of: shock has probability of 96.8527084779.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 96.6719519301.
# Actual Value: flower Prediction of: flower has probability of 12.8999186812.
# Actual Value: flower Prediction of: flower has probability of 12.4611222232.
# Actual Value: apple Prediction of: apple has probability of 95.4913828616.
# Actual Value: apple Prediction of: apple has probability of 96.9608854036.
# Actual Value: frog Prediction of: frog has probability of 87.5225515542.
# Actual Value: lemon Prediction of: lemon has probability of 7.95103906314.
# Actual Value: frog Prediction of: frog has probability of 97.3504723237.
# Actual Value: dog Prediction of: dog has probability of 9.80540886835.
# Actual Value: apple Prediction of: apple has probability of 99.4886828966.
# Actual Value: shock Prediction of: shock has probability of 31.8062058828.
# Actual Value: dog Prediction of: dog has probability of 9.55216172647.
# Actual Value: lemon Prediction of: lemon has probability of 8.22798596484.
# Actual Value: apple Prediction of: apple has probability of 94.6516209956.
# Actual Value: flower Prediction of: flower has probability of 12.0165944801.
# Actual Value: flower Prediction of: flower has probability of 12.148854877.
# Actual Value: shock Prediction of: shock has probability of 81.8673376707.
# Actual Value: flower Prediction of: flower has probability of 12.4301732387.
# Actual Value: apple Prediction of: apple has probability of 79.5750854868.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 95.6345356603.
# Actual Value: sugar Prediction of: sugar has probability of 99.3307779538.
# Actual Value: lemon Prediction of: lemon has probability of 8.5877378081.
# Actual Value: cat Prediction of: cat has probability of 98.0155263834.
# Actual Value: frog Prediction of: frog has probability of 99.6075933281.
# Actual Value: shock Prediction of: shock has probability of 72.3120575194.
# Actual Value: flower Prediction of: flower has probability of 14.3029550538.
# Actual Value: flower Prediction of: flower has probability of 13.8748960819.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 95.4395773629.
# Actual Value: flower Prediction of: flower has probability of 16.0256331728.
# Actual Value: frog Prediction of: frog has probability of 99.4644430231.
# Actual Value: dog Prediction of: dog has probability of 10.8325343828.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 95.0186369033.
# Actual Value: apple Prediction of: apple has probability of 95.4759432119.
# Actual Value: lemon Prediction of: lemon has probability of 8.77236555313.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 93.3721558595.
# Actual Value: flower Prediction of: flower has probability of 16.1586625105.
# Actual Value: sugar Prediction of: sugar has probability of 91.9294141607.
# Actual Value: shock Prediction of: shock has probability of 79.7613947102.
# Actual Value: apple Prediction of: apple has probability of 98.0901123561.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 97.991844935.
# Actual Value: shock Prediction of: shock has probability of 80.1345749297.
# Actual Value: frog Prediction of: frog has probability of 99.2546370173.
# Actual Value: frog Prediction of: frog has probability of 91.6246060987.
# Actual Value: apple Prediction of: apple has probability of 20.3335834781.
# Actual Value: apple Prediction of: apple has probability of 24.0268895641.
# Actual Value: frog Prediction of: frog has probability of 97.287748495.
# Actual Value: flower Prediction of: flower has probability of 14.6773269459.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 96.7929865024.
# Actual Value: cat Prediction of: cat has probability of 84.7415072195.
# Actual Value: apple Prediction of: apple has probability of 98.8571039336.
# Actual Value: lemon Prediction of: lemon has probability of 8.23726306804.
# Actual Value: dog Prediction of: dog has probability of 10.7411503501.
# Actual Value: shock Prediction of: shock has probability of 80.1065973865.
# Actual Value: sugar Prediction of: sugar has probability of 79.5033256122.
# Actual Value: shock Prediction of: shock has probability of 98.9678997863.
# Actual Value: dog Prediction of: dog has probability of 11.5559283026.
# Actual Value: cat Prediction of: cat has probability of 90.0941632617.
# Actual Value: apple Prediction of: apple has probability of 92.7249172177.
# Actual Value: flower Prediction of: flower has probability of 16.6093460383.
# Actual Value: shock Prediction of: shock has probability of 63.6510789791.
# Actual Value: lemon Prediction of: lemon has probability of 8.6715896944.
# Actual Value: dog Prediction of: dog has probability of 11.9043069452.
# Actual Value: dog Prediction of: dog has probability of 11.557519842.
# Actual Value: cat Prediction of: cat has probability of 87.6015288278.
# Actual Value: flower Prediction of: flower has probability of 16.0779978215.
# Actual Value: sugar Prediction of: sugar has probability of 94.1479697181.
# Actual Value: lemon Prediction of: lemon has probability of 8.70903151093.
# Actual Value: sugar Prediction of: sugar has probability of 77.8571955733.
# Actual Value: dog Prediction of: dog has probability of 11.4038678816.
# Actual Value: cat Prediction of: cat has probability of 98.7852918476.
# Actual Value: frog Prediction of: frog has probability of 99.6018895699.
# ...
# Actual Value: flower Prediction of: flower has probability of 23.6810576004.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.6080783647.
# Actual Value: sugar Prediction of: sugar has probability of 66.1535368329.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.8011538581.
# Actual Value: cat Prediction of: cat has probability of 98.7897217686.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.6002934156.
# Actual Value: shock Prediction of: shock has probability of 98.7891566039.
# Actual Value: apple Prediction of: apple has probability of 99.8265911385.
# Actual Value: sugar Prediction of: sugar has probability of 87.0859408625.
# Actual Value: sugar Prediction of: sugar has probability of 83.1942731097.
# Actual Value: frog Prediction of: frog has probability of 99.641178836.
# Actual Value: sugar Prediction of: sugar has probability of 70.3277842487.
# Actual Value: sugar Prediction of: sugar has probability of 76.5940474241.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.4476225834.
# Actual Value: cat Prediction of: cat has probability of 99.2844808331.
# Actual Value: cat Prediction of: cat has probability of 98.7757758648.
# Actual Value: flower Prediction of: flower has probability of 23.0234637214.
# Actual Value: flower Prediction of: flower has probability of 23.1217847691.
# Actual Value: shock Prediction of: shock has probability of 93.968192089.
# Actual Value: dog Prediction of: dog has probability of 15.8172418313.
# Actual Value: flower Prediction of: flower has probability of 26.0336309563.
# Actual Value: flower Prediction of: flower has probability of 23.036299079.
# Actual Value: cat Prediction of: cat has probability of 99.3425892162.
# Actual Value: lemon Prediction of: lemon has probability of 14.3033697536.
# Actual Value: frog Prediction of: frog has probability of 99.3527376754.
# Actual Value: flower Prediction of: flower has probability of 24.8047936998.
# Actual Value: cat Prediction of: cat has probability of 97.7948413753.
# Actual Value: lemon Prediction of: lemon has probability of 15.036507311.
# Actual Value: dog Prediction of: dog has probability of 17.6762440085.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.1532505638.
# Actual Value: frog Prediction of: frog has probability of 85.5318312869.
# Actual Value: lemon Prediction of: lemon has probability of 15.4190383699.
# Actual Value: cat Prediction of: cat has probability of 98.3879157861.
# Actual Value: shock Prediction of: shock has probability of 98.6280032921.
# Actual Value: frog Prediction of: frog has probability of 89.8867708141.
# Actual Value: lemon Prediction of: lemon has probability of 15.9228571041.
# Actual Value: cat Prediction of: cat has probability of 98.6654249805.
# Actual Value: shock Prediction of: shock has probability of 99.2890640072.
# Actual Value: dog Prediction of: dog has probability of 16.3609792078.
# Actual Value: shock Prediction of: shock has probability of 99.3806284002.
# Actual Value: sugar Prediction of: sugar has probability of 90.138434232.
# Actual Value: cat Prediction of: cat has probability of 98.434633056.
# Actual Value: flower Prediction of: flower has probability of 23.4279575793.
# Actual Value: apple Prediction of: apple has probability of 99.8653086325.
# Actual Value: dog Prediction of: dog has probability of 17.8515595775.
# Actual Value: dog Prediction of: dog has probability of 20.6171886374.
# Actual Value: frog Prediction of: frog has probability of 98.8339625068.
# Actual Value: cat Prediction of: cat has probability of 98.979095077.
# Actual Value: flower Prediction of: flower has probability of 25.847130412.
# Actual Value: flower Prediction of: flower has probability of 30.1268752037.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.0986624294.
# Actual Value: lemon Prediction of: lemon has probability of 16.3158426141.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 98.752130153.
# Actual Value: dog Prediction of: dog has probability of 18.6724824037.
# Actual Value: shock Prediction of: shock has probability of 86.0751270753.
# Actual Value: cat Prediction of: cat has probability of 91.3265927639.
# Actual Value: lemon Prediction of: lemon has probability of 16.3786092808.
# Actual Value: dog Prediction of: dog has probability of 18.0134508044.
# Actual Value: frog Prediction of: frog has probability of 99.0509761458.
# Actual Value: apple Prediction of: apple has probability of 96.5377184335.
# Actual Value: frog Prediction of: frog has probability of 98.0103351972.
# Actual Value: apple Prediction of: apple has probability of 99.6116676835.
# Actual Value: frog Prediction of: frog has probability of 96.6373970568.
# Actual Value: frog Prediction of: frog has probability of 91.4246155307.
# Actual Value: frog Prediction of: frog has probability of 91.3148179678.
# Actual Value: shock Prediction of: shock has probability of 98.6891490655.
# Actual Value: sugar Prediction of: sugar has probability of 92.6438438476.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.4679633904.
# Actual Value: shock Prediction of: shock has probability of 97.6843731066.
# Actual Value: dog Prediction of: dog has probability of 22.0508244349.
# Actual Value: cat Prediction of: cat has probability of 92.9456844956.
# Actual Value: lemon Prediction of: lemon has probability of 16.8471731383.
# Actual Value: sugar Prediction of: sugar has probability of 98.1652749289.
# Actual Value: frog Prediction of: frog has probability of 98.3295037899.
# Actual Value: dog Prediction of: dog has probability of 21.3391012097.
# Actual Value: cat Prediction of: cat has probability of 98.7643550139.
# Actual Value: cat Prediction of: cat has probability of 98.7746930253.
# Actual Value: cat Prediction of: cat has probability of 98.7742030672.
# Actual Value: cat Prediction of: cat has probability of 98.7843783081.
# Actual Value: dog Prediction of: dog has probability of 21.0087128271.
# Actual Value: apple Prediction of: apple has probability of 99.9190056617.
# Actual Value: sugar Prediction of: sugar has probability of 98.7001313255.
# Actual Value: shock Prediction of: shock has probability of 95.9152328277.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.3854873962.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 98.6911475775.
# Actual Value: lemon Prediction of: lemon has probability of 17.7221541307.
# Actual Value: dog Prediction of: dog has probability of 24.253038522.
# Actual Value: dog Prediction of: dog has probability of 22.8357812588.
# Actual Value: flower Prediction of: flower has probability of 30.7294820789.
# Actual Value: flower Prediction of: flower has probability of 31.2870280995.
# Actual Value: shock Prediction of: shock has probability of 70.9351947795.
# Actual Value: flower Prediction of: flower has probability of 31.3422745605.
# Actual Value: flower Prediction of: flower has probability of 31.9003338532.
# Actual Value: dog Prediction of: dog has probability of 23.5886166243.
# Actual Value: lemon Prediction of: lemon has probability of 18.0940970044.
# Actual Value: apple Prediction of: apple has probability of 34.258086295.
# Actual Value: dog Prediction of: dog has probability of 25.0840274825.
# Actual Value: flower Prediction of: flower has probability of 33.7801056053.
# Actual Value: shock Prediction of: shock has probability of 88.8523165464.
# Actual Value: flower Prediction of: flower has probability of 31.5538936862.
# Actual Value: dog Prediction of: dog has probability of 25.3457165066.
# Actual Value: apple Prediction of: apple has probability of 97.502725873.
# Actual Value: cat Prediction of: cat has probability of 93.0344687268.
# Actual Value: dog Prediction of: dog has probability of 23.6018075397.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.2624814923.
# Actual Value: shock Prediction of: shock has probability of 98.6029634168.
# Actual Value: sugar Prediction of: sugar has probability of 87.4840129628.
# Actual Value: cat Prediction of: cat has probability of 99.2906891611.
# Actual Value: shock Prediction of: shock has probability of 87.4316938087.
# Actual Value: sugar Prediction of: sugar has probability of 95.371274714.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.7458399116.
# Actual Value: cat Prediction of: cat has probability of 98.5637016941.
# Actual Value: shock Prediction of: shock has probability of 85.7721213708.
# Actual Value: cat Prediction of: cat has probability of 98.9161441798.
# Actual Value: lemon Prediction of: lemon has probability of 18.3383386216.
# Actual Value: sugar Prediction of: sugar has probability of 86.8071079631.
# Actual Value: dog Prediction of: dog has probability of 24.2320538525.
# Actual Value: dog Prediction of: dog has probability of 25.5227085087.
# Actual Value: cat Prediction of: cat has probability of 99.625664046.
# Actual Value: apple Prediction of: apple has probability of 99.9137495671.
# Actual Value: flower Prediction of: flower has probability of 32.6086966829.
# Actual Value: dog Prediction of: dog has probability of 24.3237495787.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.2911086437.
# Actual Value: flower Prediction of: flower has probability of 33.1629296086.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.6505904368.
# Actual Value: lemon Prediction of: lemon has probability of 18.8360199934.
# Actual Value: flower Prediction of: flower has probability of 33.076645521.
# Actual Value: lemon Prediction of: lemon has probability of 19.1630250578.
# Actual Value: frog Prediction of: frog has probability of 99.7365094416.
# Actual Value: frog Prediction of: frog has probability of 99.7755051498.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 98.1408931317.
# Actual Value: cat Prediction of: cat has probability of 98.2883923001.
# Actual Value: sugar Prediction of: sugar has probability of 93.376780887.
# Actual Value: frog Prediction of: frog has probability of 96.4925447019.
# Actual Value: flower Prediction of: flower has probability of 34.6991720997.
# Actual Value: dog Prediction of: dog has probability of 28.9876089891.
# Actual Value: apple Prediction of: apple has probability of 74.7275113923.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 98.9850254141.
# Actual Value: frog Prediction of: frog has probability of 90.203733611.
# Actual Value: frog Prediction of: frog has probability of 99.2620748612.
# Actual Value: cat Prediction of: cat has probability of 93.4549326802.
# Actual Value: sugar Prediction of: sugar has probability of 55.918652614.
# Actual Value: apple Prediction of: apple has probability of 95.4753691228.
# Actual Value: lemon Prediction of: lemon has probability of 19.8281985974.
# Actual Value: apple Prediction of: apple has probability of 87.9190819431.
# Actual Value: lemon Prediction of: lemon has probability of 20.3492093441.
# Actual Value: cat Prediction of: cat has probability of 96.2631170512.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 96.8672854099.
# Actual Value: sugar Prediction of: sugar has probability of 98.2074548036.
# Actual Value: sugar Prediction of: sugar has probability of 92.9286475944.
# Actual Value: flower Prediction of: flower has probability of 36.3233848852.
# Actual Value: sugar Prediction of: sugar has probability of 96.6353233064.
# Actual Value: dog Prediction of: dog has probability of 27.5585085997.
# Actual Value: flower Prediction of: flower has probability of 34.0769321925.
# Actual Value: lemon Prediction of: lemon has probability of 21.1166381311.
# Actual Value: apple Prediction of: apple has probability of 98.513664068.
# Actual Value: cat Prediction of: cat has probability of 99.2003262843.
# Actual Value: shock Prediction of: shock has probability of 99.6143935728.
# Actual Value: lemon Prediction of: lemon has probability of 22.0956775525.
# Actual Value: sugar Prediction of: sugar has probability of 32.6338194958.
# Actual Value: shock Prediction of: shock has probability of 90.8118093961.
# Actual Value: shock Prediction of: shock has probability of 98.8844840565.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.7664195017.
# Actual Value: lemon Prediction of: lemon has probability of 22.6954019291.
# Actual Value: frog Prediction of: frog has probability of 99.6973168965.
# Actual Value: shock Prediction of: shock has probability of 93.8036161968.
# Actual Value: shock Prediction of: shock has probability of 97.334405248.
# Actual Value: sugar Prediction of: sugar has probability of 92.1735449744.
# Actual Value: frog Prediction of: frog has probability of 99.7149528703.
# Actual Value: dog Prediction of: dog has probability of 27.5790281726.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.6547205512.
# Actual Value: cat Prediction of: cat has probability of 98.8577507839.
# Actual Value: sugar Prediction of: sugar has probability of 75.177521255.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.8022873812.
# Actual Value: sugar Prediction of: sugar has probability of 92.2296613543.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.7300797765.
# Actual Value: apple Prediction of: apple has probability of 99.9188546668.
# Actual Value: dog Prediction of: dog has probability of 25.8020543698.
# Actual Value: shock Prediction of: shock has probability of 99.5358953735.
# Actual Value: flower Prediction of: flower has probability of 33.6357609782.
# Actual Value: apple Prediction of: apple has probability of 61.4864604252.
# Actual Value: lemon Prediction of: lemon has probability of 23.2363747137.
# Actual Value: frog Prediction of: frog has probability of 99.7050713261.
# Actual Value: shock Prediction of: shock has probability of 96.3089107964.
# Actual Value: dog Prediction of: dog has probability of 31.1887151014.
# Actual Value: lemon Prediction of: lemon has probability of 23.6716742699.
# Actual Value: shock Prediction of: shock has probability of 99.5203047607.
# Actual Value: flower Prediction of: flower has probability of 37.2224964516.
# Actual Value: dog Prediction of: dog has probability of 30.8708210938.
# Actual Value: cat Prediction of: cat has probability of 95.9808568131.
# Actual Value: shock Prediction of: shock has probability of 94.175884466.
# Actual Value: frog Prediction of: frog has probability of 95.6864455167.
# Actual Value: apple Prediction of: apple has probability of 84.8209200985.
# Actual Value: apple Prediction of: apple has probability of 81.2683036744.
# Actual Value: dog Prediction of: dog has probability of 30.5764145104.
# Actual Value: shock Prediction of: shock has probability of 99.7938222926.
# Actual Value: lemon Prediction of: lemon has probability of 21.666543923.
# Actual Value: sugar Prediction of: sugar has probability of 99.7165542697.
# Actual Value: lemon Prediction of: lemon has probability of 22.7910577998.
# Actual Value: apple Prediction of: apple has probability of 99.3285521996.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.2773378256.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.0757054751.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.3235270288.
# Actual Value: cat Prediction of: cat has probability of 98.6510592597.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 99.0379074764.
# Actual Value: apple Prediction of: apple has probability of 99.5481285802.
# Actual Value: shock Prediction of: shock has probability of 85.8172941132.
# Actual Value: shock Prediction of: shock has probability of 51.3781157943.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 98.1472399934.
# Actual Value: frog Prediction of: frog has probability of 98.9192389629.
# Actual Value: ladyfly Prediction of: ladyfly has probability of 79.8868173705.
# Actual Value: sugar Prediction of: sugar has probability of 98.0929014687.
# Actual Value: cat Prediction of: cat has probability of 98.5422105051.
# Actual Value: sugar Prediction of: sugar has probability of 99.4534212306.
# Actual Value: cat Prediction of: cat has probability of 99.691905689.
